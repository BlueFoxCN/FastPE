# %%
from reader import *
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import os
from scipy import misc
import pickle

from cfgs.config import cfg

plt.rcParams['figure.figsize'] = [10, 10]

# %%
dp_list = []
ds = Data('val', True)
print(ds.size())
# Out:
# loading annotations into memory...
# Done (t=0.36s)
# creating index...
# index created!
# 6352

# %%
ds.reset_state()
g = ds.get_data()
for _ in range(ds.size()//1000):
    dp_list.append(next(g))

# %%
len(dp_list)
# Out:
# 6

# %%
dp = dp_list[0]

input, target, target_weight = dp
print(input.shape)
# img, heatmap, paf, mask = dp
# img = input.astype(np.uint8)

img = cv2.cvtColor(np.asarray(input,dtype=np.uint8), cv2.COLOR_BGR2RGB)
# img_shown = cv2.resize(img, (256, 256), interpolation=cv2.INTER_CUBIC)
# plt.imshow(img)
# misc.imsave("4.jpg", img)
# Out:
# (256, 192, 3)

# %%
#dp
# a=[np.max(e) for e in target]
# print(a)
# plt.imshow(np.asarray(img))
# plt.imshow(target[4,:], alpha=0.9)
# plt.imshow(target[6,:], alpha=0.5)
# all_heatmap_shown = np.amax(target[:,:], axis=0)
# print(all_heatmap_shown)
# plt.imshow(mask_shown, cmap='gray', alpha=0.5)
all_heatmap_shown=cv2.resize(np.amax(target[:,:], axis=0), (192, 256), interpolation=cv2.INTER_CUBIC)
plt.imshow(all_heatmap_shown, alpha=0.9)
plt.imshow(img, alpha=0.5)
# print(img.shape)

# %%
misc.imsave('1.jpg',input)
misc.imsave('2.jpg', cv2.resize(np.amax(target[:,:], axis=0), (192, 256), interpolation=cv2.INTER_CUBIC))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
all_heatmap_shown = cv2.resize(np.amax(heatmap[:,:, 0:18], axis=2), (368, 368), interpolation=cv2.INTER_CUBIC)
plt.imshow(img)
plt.imshow(mask_shown, cmap='gray', alpha=0.5)
plt.imshow(all_heatmap_shown, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a184a4b65528> in <module>()
# ----> 1 all_heatmap_shown = cv2.resize(np.amax(heatmap[:,:, 0:18], axis=2), (368, 368), interpolation=cv2.INTER_CUBIC)
#       2 plt.imshow(img)
#       3 plt.imshow(mask_shown, cmap='gray', alpha=0.5)
#       4 plt.imshow(all_heatmap_shown, alpha=0.5)
#
# NameError: name 'heatmap' is not defined

# %%
paf_shown_1 = cv2.resize(paf[:, :, 0], (368, 368), interpolation=cv2.INTER_CUBIC)
paf_shown_2 = cv2.resize(paf[:, :, 1], (368, 368), interpolation=cv2.INTER_CUBIC)
plt.imshow(img)
plt.imshow(paf_shown_1, alpha=.5)
plt.imshow(paf_shown_2, alpha=.5)
